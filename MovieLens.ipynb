# %%
import numpy as np
import pandas as pd

# %%
path = "E:\\tel Desktop\\python\\IBM_edx_python_DataSince\\Data\\ml-20m"

# %%
movies = pd.read_csv(f'{path}\\movies.csv' , sep = ',')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
tags = pd.read_csv(f'{path}\\tags.csv' , sep = ',')

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
ratings = pd.read_csv(f'{path}\\ratings.csv' , sep = ',' , parse_dates=['timestamp'])

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
del ratings["timestamp"]
del tags["timestamp"]

# %%
row_0 = tags.iloc[0]
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
"rating" in row_0
# Out:
# False

# %%
tags.iloc[[1,10,2000]]
# Out:
#       userId  movieId                tag
# 1         65      208          dark hero
# 10        65     1694              jesus
# 2000     910    68554  conspiracy theory

# %%
ratings["rating"].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings["rating"].mode() # the most frequent rate is 4.0
# Out:
# 0    4.0
# dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter_l = ratings["rating"] > 5
filter_l
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
#             ...
# 20000233    False
# 20000234    False
# 20000235    False
# 20000236    False
# 20000237    False
# 20000238    False
# 20000239    False
# 20000240    False
# 20000241    False
# 20000242    False
# 20000243    False
# 20000244    False
# 20000245    False
# 20000246    False
# 20000247    False
# 20000248    False
# 20000249    False
# 20000250    False
# 20000251    False
# ...

# %%
filter_l.any() # if any of them are True
# Out:
# False

# %%
filter_l = ratings["rating"] > 4
filter_l
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
#             ...
# 20000233    False
# 20000234    False
# 20000235     True
# 20000236     True
# 20000237    False
# 20000238    False
# 20000239    False
# 20000240    False
# 20000241    False
# 20000242    False
# 20000243     True
# 20000244     True
# 20000245     True
# 20000246    False
# 20000247    False
# 20000248     True
# 20000249    False
# 20000250    False
# 20000251     True
# ...

# %%
ratings["rating"][filter_l] = np.nan
# Out:
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# 5              1      112     3.5
# 6              1      151     4.0
# 7              1      223     4.0
# 8              1      253     4.0
# 9              1      260     4.0
# 10             1      293     4.0
# 11             1      296     4.0
# 12             1      318     4.0
# 13             1      337     3.5
# 14             1      367     3.5
# 15             1      541     4.0
# 16             1      589     3.5
# 17             1      593     3.5
# 18             1      653     3.0
# 19             1      919     3.5
# 20             1      924     3.5
# 21             1     1009     3.5
# 22             1     1036     4.0
# 23             1     1079     4.0
# 24             1     1080     3.5
# 25             1     1089     3.5
# ...

# %%
ratings.loc[20000259][2]
# Out:
# nan

# %%
filter_l = (ratings["rating"].isnull())
ratings[filter_l]
# Out:
#           userId  movieId  rating
# 30             1     1196     NaN
# 31             1     1198     NaN
# 131            1     4993     NaN
# 142            1     5952     NaN
# 158            1     7153     NaN
# 170            1     8507     NaN
# 171            1     8636     NaN
# 176            2       62     NaN
# 177            2       70     NaN
# 180            2      260     NaN
# 181            2      266     NaN
# 183            2      480     NaN
# 184            2      541     NaN
# 185            2      589     NaN
# 188            2      924     NaN
# 190            2     1196     NaN
# 191            2     1210     NaN
# 192            2     1214     NaN
# 193            2     1249     NaN
# 194            2     1259     NaN
# 195            2     1270     NaN
# 196            2     1327     NaN
# 197            2     1356     NaN
# 198            2     1544     NaN
# 201            2     1748     NaN
# 208            2     1974     NaN
# ...

# %%
ratings = pd.read_csv(f'{path}\\ratings.csv' , sep = ',' , parse_dates=['timestamp'])

# %%
filter_2 = ratings["rating"] > 0
filter_2.all()
# Out:
# True

# %% [markdown]
# # Data cleaning

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull()
# Out:
#        movieId  title  genres
# 0        False  False   False
# 1        False  False   False
# 2        False  False   False
# 3        False  False   False
# 4        False  False   False
# 5        False  False   False
# 6        False  False   False
# 7        False  False   False
# 8        False  False   False
# 9        False  False   False
# 10       False  False   False
# 11       False  False   False
# 12       False  False   False
# 13       False  False   False
# 14       False  False   False
# 15       False  False   False
# 16       False  False   False
# 17       False  False   False
# 18       False  False   False
# 19       False  False   False
# 20       False  False   False
# 21       False  False   False
# 22       False  False   False
# 23       False  False   False
# 24       False  False   False
# 25       False  False   False
# 26       False  False   False
# 27       False  False   False
# 28       False  False   False
# 29       False  False   False
# ...

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags = tags.dropna(axis = 0)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
tags.shape # so we have dropped (465564 - 465548) rows
# Out:
# (465548, 3)

# %%
ratings.isnull().any()
# Out:
# userId       False
# movieId      False
# rating       False
# timestamp    False
# dtype: bool

# %% [markdown]
# # Data visualization

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
# %matplotlib inline 

ratings.hist(columns = 'rating' , figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-225-b89eb064008f> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline ')
#       2
# ----> 3 ratings.hist(columns = 'rating' , figsize=(15,10))
#
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2411     for i, col in enumerate(com._try_sort(data.columns)):
#    2412         ax = _axes[i]
# -> 2413         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#    2414         ax.set_title(col)
#    2415         ax.grid(grid)
#
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
ratings.boxplot(column="rating", figsize=(15,10))

# %% [markdown]
# # slicing columns

# %%
ratings[-5:] # last 5 rows
# Out:
#           userId  movieId  rating   timestamp
# 20000258  138493    68954     4.5  1258126920
# 20000259  138493    69526     4.5  1259865108
# 20000260  138493    69644     3.0  1260209457
# 20000261  138493    70286     5.0  1258126944
# 20000262  138493    71619     2.5  1255811136

# %%
tag_counts = tags["tag"].value_counts()
tag_counts[:5]
# Out:
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot('bar' )

# %%
is_highly_rated = ratings["rating"] >= 4.0
ratings[is_highly_rated].tail()
# Out:
#           userId  movieId  rating   timestamp
# 20000256  138493    66762     4.5  1255805408
# 20000257  138493    68319     4.5  1260209720
# 20000258  138493    68954     4.5  1258126920
# 20000259  138493    69526     4.5  1259865108
# 20000261  138493    70286     5.0  1258126944

# %%
is_animation = movies['genres'].str.contains("Animation")
movies[is_animation].head()
# Out:
#      movieId                    title  \
# 0          1         Toy Story (1995)
# 12        13             Balto (1995)
# 47        48        Pocahontas (1995)
# 236      239    Goofy Movie, A (1995)
# 241      244  Gumby: The Movie (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 12                  Adventure|Animation|Children
# 47      Animation|Children|Drama|Musical|Romance
# 236            Animation|Children|Comedy|Romance
# 241                           Animation|Children

# %%
rating_counts = ratings[["movieId",'rating']].groupby('rating').count()
rating_counts
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
average_rating = ratings[["movieId",'rating']].groupby('movieId').mean()
average_rating.head()
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592

# %%
average_rating[average_rating.rating == 5]
# Out:
#          rating
# movieId
# 26718       5.0
# 27914       5.0
# 32230       5.0
# 40404       5.0
# 54326       5.0
# 72235       5.0
# 79866       5.0
# 81117       5.0
# 86055       5.0
# 88488       5.0
# 89133       5.0
# 92783       5.0
# 92956       5.0
# 93707       5.0
# 93967       5.0
# 94431       5.0
# 94657       5.0
# 94737       5.0
# 94949       5.0
# 94972       5.0
# 95517       5.0
# 95977       5.0
# 95979       5.0
# 98761       5.0
# 99243       5.0
# 99450       5.0
# 100521      5.0
# 100743      5.0
# 100830      5.0
# 101188      5.0
# ...         ...
# 121039      5.0
# 121063      5.0
# 122441      5.0
# 125599      5.0
# 126219      5.0
# 126397      5.0
# 126945      5.0
# 127256      5.0
# 128093      5.0
# 128506      5.0
# 128738      5.0
# 129034      5.0
# 129036      5.0
# 129189      5.0
# 129243      5.0
# 129293      5.0
# 129295      5.0
# 129305      5.0
# 129352      5.0
# 129478      5.0
# 129516      5.0
# 129526      5.0
# 129530      5.0
# ...

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
 movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags , on= "movieId",how = "inner")
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag
# 0    1644                                 Watched
# 1    1741                      computer animation
# 2    1741                 Disney animated feature
# 3    1741                         Pixar animation
# 4    1741  TÃ©a Leoni does not star in this movie

# %%
avg_ratings = ratings.groupby('movieId' , as_index=False).mean() #  "as_index=False" means create new indexes

# %%
del avg_ratings["userId"]

# %%
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.921240
# 1        2  3.211977
# 2        3  3.151040
# 3        4  2.861393
# 4        5  3.064592

# %%
box_office = movies.merge(avg_ratings  , on="movieId" , how = "inner")
box_office.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 1                   Adventure|Children|Fantasy  3.211977
# 2                               Comedy|Romance  3.151040
# 3                         Comedy|Drama|Romance  2.861393
# 4                                       Comedy  3.064592

# %%
is_comedy = box_office["genres"].str.contains("Comedy")
box_office[is_comedy].head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 2                               Comedy|Romance  3.151040
# 3                         Comedy|Drama|Romance  2.861393
# 4                                       Comedy  3.064592
# 6                               Comedy|Romance  3.366484

# %%
highly_rated = box_office["rating"] > 4.5

# %%
box_office[highly_rated & is_comedy]
# Out:
#        movieId                                              title  \
# 13015    62206            Supermarket Woman (Sûpâ no onna) (1996)
# 14605    73139                              Out 1: Spectre (1974)
# 16952    86055        Foster Brothers, The (Süt kardesler) (1976)
# 18190    91211    Echoes of the Rainbow (Sui yuet san tau) (2010)
# 18776    93707             Prom Queen: The Marc Hall Story (2004)
# 19710    97789           Step Up Love Story (Futari ecchi) (2002)
# 19857    98275                    Octopus, The (Le poulpe) (1998)
# 19971    98761  Shaolin Temple 2: Kids from Shaolin (Shao Lin ...
# 20085    99243                              Parasites, Les (1999)
# 21415   104317    Flight of the Conchords: A Texan Odyssey (2006)
# 21840   105841                                      B-Side (2013)
# 22264   107434                       Diplomatic Immunity (2009– )
# 22818   109571                  Into the Middle of Nowhere (2010)
# ...

# %% [markdown]
# # string operations

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_genres = movies["genres"].str.split('|' , expand = True) # By "expand = True" we are sure 
#it returns a Data Frame not a series of lists

# %%
movies_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
movies_genres["is_comedy"] = movies["genres"].str.contains("Comedy")

# %%
movies.Year_Made = movies.title.str.extract(".*\((.*)\).*")
# Out:
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
movies.Year_Made.head()
# Out:
#       0
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995

# %%
tags.dtypes
# Out:
# userId      int64
# movieId     int64
# tag        object
# dtype: object

# %%
tags["Parsed_Time"] = pd.to_datetime(tags['timestamp'],unit='s')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-252-0b5511cb68aa> in <module>
# ...

# %%
tags.tail(10)
# Out:
#         userId  movieId                               tag
# 465554  138446     3489                visually appealing
# 465555  138446     7045                   family friendly
# 465556  138446     7045  Scary Movies To See on Halloween
# 465557  138446     7164                         Peter Pan
# 465558  138446     7164                visually appealing
# 465559  138446    55999                           dragged
# 465560  138446    55999                     Jason Bateman
# 465561  138446    55999                            quirky
# 465562  138446    55999                               sad
# 465563  138472      923                     rise to power

# %%
grater_than_t = tags["Parsed_Time"] > '2015-01-23 23:30:22'
tags[grater_than_t].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Parsed_Time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-254-66597414be46> in <module>
# ...

# %%
tags.sort_values(by="Parsed_Time" , ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-255-8552f7d31028> in <module>
# ----> 1 tags.sort_values(by="Parsed_Time" , ascending=True)
#
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
# ...

# %%
tags # didn't change
# Out:
#         userId  movieId                                                tag
# 0           18     4141                                        Mark Waters
# 1           65      208                                          dark hero
# 2           65      353                                          dark hero
# 3           65      521                                      noir thriller
# 4           65      592                                          dark hero
# 5           65      668                                          bollywood
# 6           65      898                                   screwball comedy
# 7           65     1248                                      noir thriller
# 8           65     1391                                               mars
# 9           65     1617                                           neo-noir
# 10          65     1694                                              jesus
# ...

# %% [markdown]
# ## Are Movies Rating related to Year Made of them ?

# %%
average_rating = ratings.groupby('movieId' , as_index = False)
average_rating.head()
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# ...

# %%
joined = movies.merge(average_rating , on = 'movieId' ,how='inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-258-7f941c1ea571> in <module>
# ----> 1 joined = movies.merge(average_rating , on = 'movieId' ,how='inner')
#
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
joined.corr()
