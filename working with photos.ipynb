# %%
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt

# %%
photo_data = misc.imread('E:\\photoes\\406.jpg')
type(photo_data)
# Out:
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# numpy.ndarray

# %%
plt.figure(figsize = (4,4))
plt.imshow(photo_data)

# %%
num_row,num_col,chanels =photo_data.shape

# %%
photo_data.min() , photo_data.max()
# Out:
# (0, 255)

# %%
photo_data[10,250]
# Out:
# array([ 42,  36, 134], dtype=uint8)

# %%
rows_range = np.arange(len(photo_data))
cols_range = rows_range

# %%
photo_data[rows_range,cols_range] = 255

plt.figure(figsize = (4,4))
plt.imshow(photo_data)

# %%
photo_data[:len(photo_data), :len(photo_data)] = 255

plt.figure(figsize = (4,4))
plt.imshow(photo_data)

# %%
y,x = np.ogrid[:num_row,:num_col]

# %%
y
# Out:
# array([[   0],
#        [   1],
#        [   2],
#        ...,
#        [1917],
#        [1918],
#        [1919]])

# %%
x_ = np.array(num_row)
print(x_)
# Out:
# 1920

# %%
photo_data = misc.imread('E:\\photoes\\406.jpg')
# Out:
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
x_center , y_center = num_col/2 , num_row/2
distances = (x-x_center)**2 + (y-y_center)**2
r = (num_row/2)**2
T_F = (r < distances)

# %%
photo_data[T_F] = 0

# %%
plt.figure(figsize = (5,5))
plt.imshow(photo_data)

# %%
half_upper = x < x_center

half_upper_mask = np.logical_and(half_upper ,r < distances )

# %%
photo_data = misc.imread('E:\\photoes\\406.jpg')
# Out:
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
photo_data[half_upper_mask] = 255

plt.figure(figsize = (5,5))
plt.imshow(photo_data)

# %%
photo_data.shape
# Out:
# (1920, 3072, 3)

# %% [markdown]
# # containing just hight RED lights

# %%
photo_data = misc.imread('E:\\photoes\\406.jpg')
# Out:
# C:\Users\Lenovo\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
photo_data[photo_data[:,:,0] < 150] = 0

# %%
plt.figure(figsize = (5,5))
plt.imshow(photo_data)

# %%
index = photo_data[:,:,:] < 220
photo_data[index]=0

# %%
plt.figure(figsize = (15,15))
plt.imshow(photo_data)
