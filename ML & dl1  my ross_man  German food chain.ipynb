# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.structured import *
from fastai.column_data import *
np.set_printoptions(threshold=50, edgeitems=20)

PATH='D:\\FAST.Ai\\Machine Learning for coders\\Data\\rossman\\'

# %%
# from can i learn this kind of python ?
def concat_csvs(dirname):
    path = f'{PATH}{dirname}'
    filenames=glob(f"{PATH}/*.csv")

    wrote_header = False
    with open(f"{path}.csv","w") as outputfile:
        for filename in filenames:
            name = filename.split(".")[0]
            with open(filename) as f:
                line = f.readline()
                if not wrote_header:
                    wrote_header = True
                    outputfile.write("file,"+line)
                for line in f:
                     outputfile.write(name + "," + line)
                outputfile.write("\n")

# %%
table_names = ['train', 'store', 'store_states', 'state_names', 'googletrend', 'weather', 'test']
# ['store', 'store_states', 'state_names', 'weather','googletrend']

# %%
tables = [pd.read_csv(f'{PATH}{fname}.csv', low_memory=False) for fname in table_names]

# %%
from IPython.display import HTML, display

# %%
#reading fraction of data
#import pandas
#import random

#filename =f'{PATH}train.csv'
#n = sum(1 for line in open(filename)) - 1
#s = 3000 #desired sample size
#skip = sorted(random.sample(range(1,n+1),n-s)) #the 0-indexed header will not be included in the skip list
#trn_set = pandas.read_csv(filename, skiprows=skip)

# %%
#trn_set.tail()

# %%
#filename =f'{PATH}test.csv'
#n = sum(1 for line in open(filename)) - 1
#s = 800 #desired sample size
#skip = sorted(random.sample(range(1,n+1),n-s)) #the 0-indexed header will not be included in the skip list
#test_set = pandas.read_csv(filename, skiprows=skip)

# %%
#test_set.head()

# %%
#tables.append(test_set)

# %%
#tables.append(trn_set)

# %%
for t in tables : display(t.head())
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# ...

# %%
for t in tables : display(DataFrameSummary(t).summary())
# Out:
#                     Store    DayOfWeek         Date        Sales    Customers  \
# count         1.01721e+06  1.01721e+06          NaN  1.01721e+06  1.01721e+06
# mean               558.43      3.99834          NaN      5773.82      633.146
# std               321.909      1.99739          NaN      3849.93      464.412
# min                     1            1          NaN            0            0
# 25%                   280            2          NaN         3727          405
# 50%                   558            4          NaN         5744          609
# 75%                   838            6          NaN         7856          837
# max                  1115            7          NaN        41551         7388
# counts            1017209      1017209      1017209      1017209      1017209
# uniques              1115            7          942        21734         4086
# missing                 0            0            0            0            0
# ...

# %%
train, store, store_states, state_names, googletrend, weather, test = tables

# %%
len(train),len(test)
# Out:
# (1017209, 41088)

# %%
train.StateHoliday[0]
# Out:
# '0'

# %%
# convert to boolian
train.StateHoliday = (train.StateHoliday != '0') # what if we used "... != 0"
test.StateHoliday = (test.StateHoliday != '0')

# %%
def join_df(left,right,left_on , right_on = None , suffix = '_y'):
    if right_on is None :
        right_on = left_on
    return left.merge(right,how = 'left',left_on=left_on,right_on = right_on ,suffixes=("", suffix))

# %%
weather[1000:1003]
# Out:
#                file        Date  Max_TemperatureC  Mean_TemperatureC  \
# 1000  Niedersachsen  2013-01-11                 0                 -2
# 1001  Niedersachsen  2013-01-12                 0                 -3
# 1002  Niedersachsen  2013-01-13                -2                 -4
#
#       Min_TemperatureC  Dew_PointC  MeanDew_PointC  Min_DewpointC  \
# 1000                -4          -2              -3             -5
# 1001                -7          -3              -4             -7
# 1002                -6          -2              -3             -5
#
#       Max_Humidity  Mean_Humidity       ...        Max_VisibilityKm  \
# 1000           100             89       ...                    31.0
# 1001           100             91       ...                    31.0
# 1002           100             93       ...                    19.0
#
#       Mean_VisibilityKm  Min_VisibilitykM  Max_Wind_SpeedKm_h  \
# 1000               11.0               3.0                  14
# ...

# %%
state_names.head(3)
# Out:
#            StateName State
# 0  BadenWuerttemberg    BW
# 1             Bayern    BY
# 2             Berlin    BE

# %%
weather = join_df(weather,state_names,"file","StateName")

# %%
googletrend.head(3)
# Out:
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91

# %%
googletrend['Date'] = googletrend.week.str.split(" - ",expand = True)[0]
googletrend['State'] = googletrend.file.str.split("_",expand = True)[2]

# %%
(googletrend.State == "NI").any()
# Out:
# True

# %%
googletrend.loc[googletrend.State=='NI', "State"] = 'HB,NI'

# %%
add_datepart(weather,"Date",drop=False)

# %%
add_datepart(googletrend,"Date",drop=False)
add_datepart(train,"Date",drop=False)
add_datepart(test,"Date",drop=False)

# %%
trend_de = googletrend[googletrend.file == "Rossmann_DE"] # for whole of Germany

# %%
store = join_df(store,store_states,"Store")
len(store[store.State.isnull()]) # so zero means we hadn't any additional thing in left data_set (store)
# Out:
# 0

# %%
joined = join_df(train,store,"Store")
joined_test = join_df(test ,store,"Store")
len(joined[joined.StoreType.isnull()]),len(joined_test[joined_test.StoreType.isnull()])
# Out:
# (0, 0)

# %%
joined.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1         False
# 1      2          5 2015-07-31   6064        625     1      1         False
# 2      3          5 2015-07-31   8314        821     1      1         False
# 3      4          5 2015-07-31  13995       1498     1      1         False
# 4      5          5 2015-07-31   4822        559     1      1         False
#
#    SchoolHoliday  Year  ...    StoreType  Assortment  CompetitionDistance  \
# 0              1  2015  ...            c           a               1270.0
# 1              1  2015  ...            a           a                570.0
# 2              1  2015  ...            a           a              14130.0
# 3              1  2015  ...            c           c                620.0
# 4              1  2015  ...            a           a              29910.0
#
# ...

# %%
googletrend.week
# Out:
# 0       2012-12-02 - 2012-12-08
# 1       2012-12-09 - 2012-12-15
# 2       2012-12-16 - 2012-12-22
# 3       2012-12-23 - 2012-12-29
# 4       2012-12-30 - 2013-01-05
# 5       2013-01-06 - 2013-01-12
# 6       2013-01-13 - 2013-01-19
# 7       2013-01-20 - 2013-01-26
# 8       2013-01-27 - 2013-02-02
# 9       2013-02-03 - 2013-02-09
# 10      2013-02-10 - 2013-02-16
# 11      2013-02-17 - 2013-02-23
# 12      2013-02-24 - 2013-03-02
# 13      2013-03-03 - 2013-03-09
# 14      2013-03-10 - 2013-03-16
# 15      2013-03-17 - 2013-03-23
# 16      2013-03-24 - 2013-03-30
# 17      2013-03-31 - 2013-04-06
# 18      2013-04-07 - 2013-04-13
# 19      2013-04-14 - 2013-04-20
# 20      2013-04-21 - 2013-04-27
# 21      2013-04-28 - 2013-05-04
# 22      2013-05-05 - 2013-05-11
# 23      2013-05-12 - 2013-05-18
# 24      2013-05-19 - 2013-05-25
# 25      2013-05-26 - 2013-06-01
# 26      2013-06-02 - 2013-06-08
# 27      2013-06-09 - 2013-06-15
# 28      2013-06-16 - 2013-06-22
# ...

# %%
weather.Week
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1
# 6         2
# 7         2
# 8         2
# 9         2
# 10        2
# 11        2
# 12        2
# 13        3
# 14        3
# 15        3
# 16        3
# 17        3
# 18        3
# 19        3
# 20        4
# 21        4
# 22        4
# 23        4
# 24        4
# 25        4
# 26        4
# 27        5
# 28        5
# 29        5
#          ..
# 15810    34
# 15811    34
# 15812    34
# 15813    34
# 15814    34
# 15815    35
# 15816    35
# 15817    35
# 15818    35
# 15819    35
# 15820    35
# 15821    35
# 15822    36
# 15823    36
# 15824    36
# 15825    36
# 15826    36
# 15827    36
# 15828    36
# 15829    37
# 15830    37
# 15831    37
# 15832    37
# 15833    37
# 15834    37
# 15835    37
# 15836    38
# 15837    38
# 15838    38
# 15839    38
# Name: Week, Length: 15840, dtype: int64

# %%
train.Date
# Out:
# 0         2015-07-31
# 1         2015-07-31
# 2         2015-07-31
# 3         2015-07-31
# 4         2015-07-31
# 5         2015-07-31
# 6         2015-07-31
# 7         2015-07-31
# 8         2015-07-31
# 9         2015-07-31
# 10        2015-07-31
# 11        2015-07-31
# 12        2015-07-31
# 13        2015-07-31
# 14        2015-07-31
# 15        2015-07-31
# 16        2015-07-31
# 17        2015-07-31
# 18        2015-07-31
# 19        2015-07-31
# 20        2015-07-31
# 21        2015-07-31
# 22        2015-07-31
# 23        2015-07-31
# 24        2015-07-31
# 25        2015-07-31
# 26        2015-07-31
# 27        2015-07-31
# 28        2015-07-31
# 29        2015-07-31
#              ...
# 1017179   2013-01-01
# 1017180   2013-01-01
# 1017181   2013-01-01
# 1017182   2013-01-01
# 1017183   2013-01-01
# 1017184   2013-01-01
# 1017185   2013-01-01
# 1017186   2013-01-01
# 1017187   2013-01-01
# 1017188   2013-01-01
# 1017189   2013-01-01
# 1017190   2013-01-01
# ...

# %%
joined = join_df(joined, googletrend, ["State","Year", "Week"]) # key(on = ...) is: when all 
                                                                #["State","Year", "Week"] are matched

# %%
joined_test = join_df(joined, googletrend, ["State","Year", "Week"])
len(joined[joined.trend.isnull()]),len(joined_test[joined_test.trend.isnull()])
# Out:
# (0, 0)

# %%
len(trend_de) , len(googletrend) , len(joined)
# Out:
# (148, 2072, 1017209)

# %%
joined = joined.merge(trend_de, 'left', ["Year", "Week"], suffixes=('', '_DE'))
joined_test = joined_test.merge(trend_de, 'left', ["Year", "Week"], suffixes=('', '_DE'))
len(joined[joined.trend_DE.isnull()]),len(joined_test[joined_test.trend_DE.isnull()])
# Out:
# (0, 0)

# %%
joined = join_df(joined, weather, ["State","Date"])
joined_test = join_df(joined_test, weather, ["State","Date"])
len(joined[joined.Mean_TemperatureC.isnull()]),len(joined_test[joined_test.Mean_TemperatureC.isnull()])
# Out:
# (0, 0)

# %%
for df in (joined , joined_test):
    for c in df.columns:
        if c.endswith("_y"):
            if c in df.columns : df.drop(c,inplace = True , axis =1)

# %%
for df in (joined,joined_test):
    df['CompetitionOpenSinceYear'] = df.CompetitionOpenSinceYear.fillna(1900).astype(np.int32)
    df['CompetitionOpenSinceMonth'] = df.CompetitionOpenSinceMonth.fillna(1).astype(np.int32)
    df['Promo2SinceYear'] = df.Promo2SinceYear.fillna(1900).astype(np.int32)
    df['Promo2SinceWeek'] = df.Promo2SinceWeek.fillna(1).astype(np.int32)

# %%
for df in (joined,joined_test):
    df["CompetitionOpenSince"] = pd.to_datetime(dict(year=df.CompetitionOpenSinceYear, 
                                                     month=df.CompetitionOpenSinceMonth, day=15))
    df["CompetitionDaysOpen"] = df.Date.subtract(df.CompetitionOpenSince).dt.days

# %%
for df in (joined,joined_test):
    df.loc[df.CompetitionDaysOpen<0, "CompetitionDaysOpen"] = 0
    df.loc[df.CompetitionOpenSinceYear<1990, "CompetitionDaysOpen"] = 0

# %%
for df in (joined,joined_test):
    df["CompetitionMonthsOpen"] = df["CompetitionDaysOpen"]//30
    df.loc[df.CompetitionMonthsOpen>24, "CompetitionMonthsOpen"] = 24
joined.CompetitionMonthsOpen.unique()
# Out:
# array([24,  3, 19,  9,  0, 16, 17,  7, 15, 22, 11, 13,  2, 23, 12,  4, 10,  1, 14, 20,  8, 18,  6, 21,  5],
#       dtype=int64)

# %%
def create_promo2since(x):
    return Week(x.Promo2SinceYear , x.Promo2SinceWeek).monday()

# %%
for df in (joined , joined_test):
    df["Promo2Since"] = pd.to_datetime(df.apply(create_promo2since , axis =1).astype(pd.datetime))
    df["Promo2Days"] = df.Date.subtract(df["Promo2Since"]).dt.days

# %%
for df in (joined,joined_test):
    df.loc[df.Promo2Days<0, "Promo2Days"] = 0
    df.loc[df.Promo2SinceYear<1990, "Promo2Days"] = 0
    df["Promo2Weeks"] = df["Promo2Days"]//7
    df.loc[df.Promo2Weeks<0, "Promo2Weeks"] = 0
    df.loc[df.Promo2Weeks>25, "Promo2Weeks"] = 25
    df.Promo2Weeks.unique()

# %% [markdown]
# # Saving and Loading

# %%
joined.to_feather(f'{PATH}joined')
joined_test.to_feather(f'{PATH}joined_test')

# %%
import feather
joined = feather.read_dataframe(f'{PATH}joined')
joined_test = feather.read_dataframe(f'{PATH}joined_test')

# %% [markdown]
# # Durations

# %%
def get_elapsed(fld , pre):
    res = []
    day1 = np.timedelta64(1,"D")
    last_date = np.datetime64()
    last_store = 0
    
    for s,v,d in zip(df.Store.values , df[fld].values , df.Date.values): # using df.fld is an Error 
        if s != last_store : 
            last_date = np.datetime64()
            last_store = s
        if v : last_date = d
        res.append(((d-last_date).astype('timedelta64[D]') / day1))
    df[pre+fld] = res

# %%
train.Date[0] - train.Date[100000]
# Out:
# Timedelta('89 days 00:00:00')

# %%
train.Date.values[0] - train.Date.values[100000]
# Out:
# numpy.timedelta64(7689600000000000,'ns')

# %%
(train.Date.values[0] - train.Date.values[100000]).astype('timedelta64[D]')
# Out:
# numpy.timedelta64(89,'D')

# %%
day1 = np.timedelta64(1, 'D')
(train.Date.values[0] - train.Date.values[100000]).astype('timedelta64[D]')/day1
# Out:
# 89.0

# %%
type((train.Date.values[0] - train.Date.values[100000]).astype('timedelta64[D]')/day1)
# Out:
# numpy.float64

# %%
columns = ["Date", "Store", "Promo", "StateHoliday", "SchoolHoliday"]

# %% [markdown]
# # for test and train , do these two level in order

# %%
#df = train[columns]

# %%
df = test[columns]

# %%
fld = "SchoolHoliday"
df =  df.sort_values(["Store","Date"])
get_elapsed(fld,"After")
df =  df.sort_values(["Store","Date"] , ascending = [True , False]) # equal to ascending= False
get_elapsed(fld,"Before")

# %%
fld = 'StateHoliday'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %%
fld = 'Promo'
df = df.sort_values(['Store', 'Date'])
get_elapsed(fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
get_elapsed(fld, 'Before')

# %%
df = df.set_index("Date")

# %%
columns = ['SchoolHoliday', 'StateHoliday', 'Promo']

# %%
for o in ["Before" , "After"]:
    for p in columns:
        a = o + p
        df[a] = df[a].fillna(0).astype(int)

# %%
len(df[['Store']+columns])
# Out:
# 41088

# %%
len(df[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum())
# Out:
# 41088

# %%
DF = df[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1)

# %%
#len(DF.Store) , len(DF.Store.unique())

# %%
bwd = df[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum()

# %%
fwd = df[['Store']+columns].sort_index(ascending = False
                                      ).groupby("Store").rolling(7, min_periods=1).sum()

# %%
bwd.head()
# Out:
#                   Store  SchoolHoliday  StateHoliday  Promo
# Store Date
# 1     2015-08-01    1.0            1.0           0.0    0.0
#       2015-08-02    2.0            2.0           0.0    0.0
#       2015-08-03    3.0            3.0           0.0    1.0
#       2015-08-04    4.0            4.0           0.0    2.0
#       2015-08-05    5.0            5.0           0.0    3.0

# %%
bwd.drop('Store',1,inplace=True)

# %%
bwd.head()
# Out:
#                   SchoolHoliday  StateHoliday  Promo
# Store Date
# 1     2015-08-01            1.0           0.0    0.0
#       2015-08-02            2.0           0.0    0.0
#       2015-08-03            3.0           0.0    1.0
#       2015-08-04            4.0           0.0    2.0
#       2015-08-05            5.0           0.0    3.0

# %%
bwd.reset_index(inplace=True)

# %%
bwd.head()
# Out:
#    Store       Date  SchoolHoliday  StateHoliday  Promo
# 0      1 2015-08-01            1.0           0.0    0.0
# 1      1 2015-08-02            2.0           0.0    0.0
# 2      1 2015-08-03            3.0           0.0    1.0
# 3      1 2015-08-04            4.0           0.0    2.0
# 4      1 2015-08-05            5.0           0.0    3.0

# %%
df = df.merge(bwd, 'left', ['Date', 'Store'], suffixes=['', '_bw'])

# %%
fwd.drop('Store',1,inplace=True)
fwd.reset_index(inplace=True)

# %%
df = df.merge(fwd, 'left', ['Date', 'Store'], suffixes=['', '_fw'])

# %%
df.drop(columns,1,inplace=True)

# %%
df.to_feather(f'{PATH}df')

# %%
df = feather.read_dataframe(f'{PATH}df')

# %%
df["Date"] = pd.to_datetime(df.Date)

# %%
df.columns
# Out:
# Index(['Date', 'Store', 'AfterSchoolHoliday', 'BeforeSchoolHoliday',
#        'AfterStateHoliday', 'BeforeStateHoliday', 'AfterPromo', 'BeforePromo',
#        'SchoolHoliday_bw', 'StateHoliday_bw', 'Promo_bw', 'SchoolHoliday_fw',
#        'StateHoliday_fw', 'Promo_fw'],
#       dtype='object')

# %%
#joined = join_df(joined, df, ['Store', 'Date'])

# %%
joined_test = join_df(joined_test, df, ['Store', 'Date'])

# %%
#joined = joined[joined.Sales!=0]

# %%
#joined.reset_index(inplace=True)

# %%
joined_test.reset_index(inplace=True)

# %%
#joined.to_feather(f'{PATH}joined')

# %%
joined_test.to_feather(f'{PATH}joined_test')

# %% [markdown]
# # Create features

# %%
import feather
joined = feather.read_dataframe(f'{PATH}joined')

# %%
joined_test = feather.read_dataframe(f'{PATH}joined_test')

# %%
joined.head().T.head(40)
# Out:
#                                                  0                        1  \
# index                                            0                        1
# Store                                            1                        2
# DayOfWeek                                        5                        5
# Date                           2015-07-31 00:00:00      2015-07-31 00:00:00
# Sales                                         5263                     6064
# Customers                                      555                      625
# Open                                             1                        1
# Promo                                            1                        1
# StateHoliday                                 False                    False
# SchoolHoliday                                    1                        1
# Year                                          2015                     2015
# ...

# %%
joined_test.head().T.head(40)
# Out:
#                                                  0                        1  \
# level_0                                          0                        1
# index                                            0                        1
# Store                                            1                        2
# DayOfWeek                                        5                        5
# Date                           2015-07-31 00:00:00      2015-07-31 00:00:00
# Sales                                         5263                     6064
# Customers                                      555                      625
# Open                                             1                        1
# Promo                                            1                        1
# StateHoliday                                 False                    False
# SchoolHoliday                                    1                        1
# ...

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen',
    'Promo2Weeks', 'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear',
    'State', 'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_fw', 'StateHoliday_bw',
    'SchoolHoliday_fw', 'SchoolHoliday_bw']

contin_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday', 'BeforeStateHoliday', 'Promo', 'SchoolHoliday']

# %%
n= len(joined) ; n
# Out:
# 844338

# %%
dep = 'Sales'
joined = joined[contin_vars + cat_vars +["Date" , dep]].copy()

# %%
joined_test[dep] = 0
joined_test = joined_test[cat_vars+contin_vars+[dep, 'Date']].copy() # , 'Id'

# %%
for v in cat_vars : joined[v] = joined[v].astype("category").cat.as_ordered()

# %%
apply_cats(joined_test , joined)

# %%
for v in contin_vars :
    joined[v] = joined[v].fillna(0).astype("float32")
    joined_test[v] = joined_test[v].fillna(0).astype("float32")

# %% [markdown]
# # Run sub_sample and Whole Data in Order

# %%
idxs = get_cv_idxs(n , val_pct=100000/n)
joined_sample = joined.iloc[idxs].set_index("Date")
samp_size = len(joined_sample)
samp_size
# Out:
# 100000

# %%
#samp_size = n
#joined_sample = joined.set_index("Date")

# %%
df,y,nas,mapper = proc_df(joined_sample,"Sales",do_scale=True)
# mapper > for each continous variable what is mean and std 
yl = np.log(y)

# %%
df.Year
# Out:
# Date
# 2015-06-16    3
# 2013-10-30    1
# 2014-11-05    2
# 2013-06-19    1
# 2014-04-28    2
# 2013-10-30    1
# 2015-03-20    3
# 2015-04-13    3
# 2014-06-28    2
# 2015-07-24    3
# 2013-02-27    1
# 2015-01-23    3
# 2013-05-06    1
# 2014-12-18    2
# 2014-12-11    2
# 2013-06-22    1
# 2015-02-19    3
# 2013-03-07    1
# 2014-02-13    2
# 2013-02-22    1
# 2013-01-17    1
# 2013-10-29    1
# 2015-01-13    3
# 2013-10-01    1
# 2014-08-07    2
# 2015-02-10    3
# 2013-08-19    1
# 2015-01-26    3
# 2014-06-05    2
# 2014-12-20    2
#              ..
# 2014-05-12    2
# 2014-06-27    2
# 2014-06-04    2
# 2014-05-03    2
# 2013-05-24    1
# 2015-06-09    3
# 2015-07-22    3
# 2014-08-15    2
# 2014-04-08    2
# 2014-01-13    2
# 2014-02-13    2
# 2014-03-06    2
# 2015-05-22    3
# 2013-08-03    1
# 2014-05-12    2
# 2015-01-08    3
# 2014-05-30    2
# 2014-01-25    2
# 2014-01-20    2
# 2013-04-24    1
# 2013-09-09    1
# 2013-05-25    1
# 2013-04-13    1
# 2015-01-22    3
# ...

# %%
joined_test = joined_test.set_index("Date")
joined_test
# Out:
#            Store DayOfWeek  Year Month Day StateHoliday CompetitionMonthsOpen  \
# Date
# 2015-07-31     1         5  2015     7  31        False                    24
# 2015-07-31     2         5  2015     7  31        False                    24
# 2015-07-31     3         5  2015     7  31        False                    24
# 2015-07-31     4         5  2015     7  31        False                    24
# 2015-07-31     5         5  2015     7  31        False                     3
# 2015-07-31     6         5  2015     7  31        False                    19
# 2015-07-31     7         5  2015     7  31        False                    24
# 2015-07-31     8         5  2015     7  31        False                     9
# 2015-07-31     9         5  2015     7  31        False                    24
# 2015-07-31    10         5  2015     7  31        False                    24
# 2015-07-31    11         5  2015     7  31        False                    24
# ...

# %%
df_test ,_ , nas , mapper = proc_df(joined_test , "Sales" , do_scale=True , mapper= mapper 
                                    , na_dict=nas)

# %%
Q = (df.index<=datetime.datetime(2014,9,17)) & (df.index>=datetime.datetime(2014,8,1))

# %%
len(df[Q]) , len(df)
# Out:
# (4497, 100000)

# %%
val_idx = np.flatnonzero(Q)

# %%
# val_idx = [0] # for retraining on whole thing

# %% [markdown]
# # DL

# %%
def inv_y(a) : return np.exp(a)

def exp_rmspe(y_pred , targ):
    targ = inv_y(targ)
    pct_var = (targ - inv_y(y_pred))/targ
    return math.sqrt((pct_var**2).mean())

# %%
max_log_y = np.max(yl)
y_range = (0, max_log_y*1.2)

# %%
md = ColumnarModelData.from_data_frame(PATH , val_idx , df , yl.astype("float32") 
                                  , cat_flds=cat_vars ,bs =128, test_df = df_test)

# %%
cat_sz = [(c, len(joined_sample[c].cat.categories)+1) for c in cat_vars]

# %%
cat_sz
# Out:
# [('Store', 1116),
#  ('DayOfWeek', 8),
#  ('Year', 4),
#  ('Month', 13),
#  ('Day', 32),
#  ('StateHoliday', 3),
#  ('CompetitionMonthsOpen', 26),
#  ('Promo2Weeks', 27),
#  ('StoreType', 5),
#  ('Assortment', 4),
#  ('PromoInterval', 4),
#  ('CompetitionOpenSinceYear', 24),
#  ('Promo2SinceYear', 9),
#  ('State', 13),
#  ('Week', 53),
#  ('Events', 22),
#  ('Promo_fw', 7),
#  ('Promo_bw', 7),
#  ('StateHoliday_fw', 4),
#  ('StateHoliday_bw', 4),
#  ('SchoolHoliday_fw', 9),
#  ('SchoolHoliday_bw', 9)]

# %%
emb_sz = [(c , min(50,(c+1//2))) for _,c in cat_sz]
emb_sz
# Out:
# [(1116, 50),
#  (8, 8),
#  (4, 4),
#  (13, 13),
#  (32, 32),
#  (3, 3),
#  (26, 26),
#  (27, 27),
#  (5, 5),
#  (4, 4),
#  (4, 4),
#  (24, 24),
#  (9, 9),
#  (13, 13),
#  (53, 50),
#  (22, 22),
#  (7, 7),
#  (7, 7),
#  (4, 4),
#  (4, 4),
#  (9, 9),
#  (9, 9)]

# %%
m = md.get_learner(emb_sz , len(df.columns)-len(cat_vars) , 0.04 
                   ,1,[1000,500] , [0.001,0.01],y_range= y_range )

# %%
lr = 1e-3

# %%
m.lr_find()
# Out:
# ...
#  62%|██████████████████████████████████████████▍                         | 466/747 [00:14<00:08, 32.15it/s, loss=0.287]

# %%
m.sched.plot(100)

# %%
m.fit(lr, 3, metrics=[exp_rmspe])
# Out:
# ...
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.030121   0.042094   0.185157
#     1      0.021565   0.028875   0.173434
#     2      0.017417   0.037563   0.17265
# [array([0.03756]), 0.1726504195605026]

# %%
m.fit(lr, 5, metrics=[exp_rmspe], cycle_len=1)
# Out:
# ...
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.013043   0.029504   0.155671
#     1      0.011489   0.028761   0.154613
#     2      0.010499   0.025978   0.14834
#     3      0.009751   0.023354   0.141606
#     4      0.010255   0.022435   0.139955
# [array([0.02243]), 0.13995494150362267]

# %%
m.fit(lr, 2, metrics=[exp_rmspe], cycle_len=4)
# Out:
# ...
# epoch      trn_loss   val_loss   exp_rmspe
#     0      0.012969   0.021417   0.139945
#     1      0.010208   0.032219   0.161685
#     2      0.007616   0.020551   0.135984
#     3      0.006607   0.020811   0.13605
#     4      0.010551   0.019628   0.135196
#     5      0.008422   0.020514   0.135836
#     6      0.006458   0.019329   0.1325
#     7      0.005619   0.020077   0.134314
# [array([0.02008]), 0.1343143127841993]
